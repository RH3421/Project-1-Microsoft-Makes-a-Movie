# %%
import pandas as pd
import gzip as gz
import sqlite3
from zipfile import ZipFile

# %%
imdb = 'data/im.db.zip'
with ZipFile(imdb, 'r') as zip:
    zip.extractall('data/imdb_unzipped')

conn = sqlite3.connect('data/imdb_unzipped/im.db')
        
q = """
SELECT *
FROM sqlite_master
"""
pd.read_sql(q, conn)
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
q = """
SELECT *
FROM movie_basics
ORDER BY start_year
"""
pd.read_sql(q, conn)
# Out:
#           movie_id                              primary_title  \
# 0        tt0146592                                Pál Adrienn
# 1        tt0154039                       So Much for Justice!
# 2        tt0162942               Children of the Green Dragon
# 3        tt0230212                          The Final Journey
# 4        tt0312305     Quantum Quest: A Cassini Space Odyssey
# ...            ...                                        ...
# 146139   tt6149054  Fantastic Beasts and Where to Find Them 5
# 146140   tt3095356                                   Avatar 4
# 146141  tt10300398                    Untitled Star Wars Film
# 146142   tt5637536                                   Avatar 5
# 146143   tt5174640                                  100 Years
#
#                                    original_title  start_year  \
# 0                                     Pál Adrienn        2010
# 1                                  Oda az igazság        2010
# 2                        A zöld sárkány gyermekei        2010
# 3                               The Final Journey        2010
# 4          Quantum Quest: A Cassini Space Odyssey        2010
# ...                                           ...         ...
# 146139  Fantastic Beasts and Where to Find Them 5        2024
# 146140                                   Avatar 4        2025
# 146141                    Untitled Star Wars Film        2026
# 146142                                   Avatar 5        2027
# 146143                                  100 Years        2115
#
#         runtime_minutes                      genres
# 0                 136.0                       Drama
# 1                 100.0                     History
# 2                  89.0                       Drama
# 3                 120.0                       Drama
# 4                  45.0  Adventure,Animation,Sci-Fi
# ...                 ...                         ...
# 146139              NaN    Adventure,Family,Fantasy
# 146140              NaN    Action,Adventure,Fantasy
# 146141              NaN                     Fantasy
# 146142              NaN    Action,Adventure,Fantasy
# 146143              NaN                       Drama
#
# [146144 rows x 6 columns]

# %%
#Include movies released over a 10 year period from 2012 to 2021
#Dropped redundant original_title column.

q = """
SELECT movie_id, primary_title AS 'Movie Title', start_year, runtime_minutes, genres
FROM movie_basics
WHERE start_year BETWEEN 2012 AND 2021
ORDER BY start_year 
"""
movie_clean = pd.read_sql(q, conn)

# %%
movie_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121352 entries, 0 to 121351
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         121352 non-null  object
#  1   Movie Title      121352 non-null  object
#  2   start_year       121352 non-null  int64
#  3   runtime_minutes  93709 non-null   float64
#  4   genres           116821 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.6+ MB

# %%
movie_clean.head()
# Out:
#     movie_id            Movie Title  start_year  runtime_minutes  \
# 0  tt0139613             O Silêncio        2012              NaN
# 1  tt0144449  Nema aviona za Zagreb        2012             82.0
# 2  tt0249516             Foodfight!        2012             91.0
# 3  tt0250404              Godfather        2012              NaN
# 4  tt0262218      Akakis mogzauroba        2012             44.0
#
#                     genres
# 0      Documentary,History
# 1                Biography
# 2  Action,Animation,Comedy
# 3              Crime,Drama
# 4              Documentary

# %%
#List of genres in movie_clean
list_of_genres = ['Action',
 'Adventure',
 'Animation',
 'Biography',
 'Comedy',
 'Crime',
 'Documentary',
 'Drama',
 'Family',
 'Fantasy',
 'Game-Show',
 'History',
 'Horror',
 'Music',
 'Musical',
 'Mystery',
 'News',
 'Reality-TV',
 'Romance',
 'Sci-Fi',
 'Sport',
 'Talk-Show',
 'Thriller',
 'War',
 'Western']

# %%
#Matching test with Movie Title in BudgetsDF
match_test = movie_clean[(movie_clean['Movie Title'] == 'Avengers: Age of Ultron')]
match_test
# Out:
#         movie_id              Movie Title  start_year  runtime_minutes  \
# 44848  tt2395427  Avengers: Age of Ultron        2015            141.0
#
#                         genres
# 44848  Action,Adventure,Sci-Fi
